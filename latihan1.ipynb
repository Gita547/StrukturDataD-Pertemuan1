# %% [markdown]
# <a href="https://colab.research.google.com/github/Gita547/StrukturDataD-Pertemuan1/blob/main/latihan1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mahasiswa = ["Udin", "Andika", "Gita", "Dio", "Putri"]
print("List Mahasiswa:")
print(mahasiswa)
# Out:
# List Mahasiswa:
# ['Udin', 'Andika', 'Gita', 'Dio', 'Putri']

# %%
Tambah 1 Nama Baru dengan append

# %%
mahasiswa.append("Budi")
print("List yang diperbarui")
print(mahasiswa)
# Out:
# List yang diperbarui
# ['Udin', 'Andika', 'Gita', 'Dio', 'Putri', 'Budi']

# %%
Hapus salah satu nama
